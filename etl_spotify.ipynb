# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
import pandas as pd

# %%
client_id = 'deaeea63e1f8416dbb31eb0100890c67'
client_secret ='cb860ea90bcb474abfd9cae519902ff4'

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
playlist_url = 'https://open.spotify.com/playlist/5ABHKGoOzxkaa28ttQV9sE'

# %%
new_url =playlist_url.split('/')[-1]

# %%
new_url
# Out:
# '5ABHKGoOzxkaa28ttQV9sE'

# %%
data = spotify.playlist_tracks(new_url)

# %%
len(data['items'])
# Out:
# 100

# %%
#album_id, albulm_name, release_date, total_tracks, url

# %%
data['items'][0]
# Out:
# {'added_at': '2023-08-19T07:38:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
# ...

# %%
#album_id

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
#album_name
data['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
#album_date
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
#total_tracks
data['items'][0]['track']['album']['total_tracks']
# Out:
# 14

# %%
#url
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_id, albulm_name, release_date, total_tracks, url=[],[],[],[],[]

# %%
album_id, albulm_name, release_date, total_tracks, url=[],[],[],[],[]
for item in data['items']:
    album_id.append(item['track']['album']['id'])
    albulm_name.append(item['track']['album']['name'])
    release_date.append(item['track']['album']['release_date'])
    total_tracks.append(item['track']['album']['total_tracks'])
    url.append(item['track']['album']['external_urls']['spotify'])

# %%
len(album_id)
# Out:
# 100

# %%
spotify_dict = { 

'album_id' :album_id,
'albulm_name' : albulm_name,
'release_date' : release_date,
'total_tracks' :  total_tracks,
'url': url

}

# %%
album_df = pd.DataFrame(spotify_dict)

# %%
album_df
# Out:
#                   album_id                                        albulm_name  \
# 0   4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3   0UywfDKYlyiu1b38DRrzYD        Dance Monkey (Stripped Back) / Dance Monkey
# 4   35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
# ..                     ...                                                ...
# 95  12zhNm6ybv6ouz6J8b9qWu                                             Piñata
# 96  6tOe4eAF8xNhEkl9WyvsE4  (What's The Story) Morning Glory? (Deluxe Rema...
# 97  5Nux7ozBJ5KJ02QYWwrneR                  I Don't Care (with Justin Bieber)
# 98  4PgleR09JVnm3zY1fW3XBA                                          24K Magic
# 99  270o30h7cAlEhBnbuSpFZq                                          El Dorado
#
#    release_date  total_tracks  \
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   albulm_name   100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
#REMOVING DUPLICATE
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                   album_id                                        albulm_name  \
# 0   4yP0hdKOZPNshxUOjY0cZj                                        After Hours
# 1   3T4tUhGYeRNVUGevb0wThu                                         ÷ (Deluxe)
# 2   5658aM19fA3JVwTK6eQX70            Divinely Uninspired To A Hellish Extent
# 3   0UywfDKYlyiu1b38DRrzYD        Dance Monkey (Stripped Back) / Dance Monkey
# 4   35s58BRTGAEWztPo9WqCIs  Spider-Man: Into the Spider-Verse (Soundtrack ...
# ..                     ...                                                ...
# 95  12zhNm6ybv6ouz6J8b9qWu                                             Piñata
# 96  6tOe4eAF8xNhEkl9WyvsE4  (What's The Story) Morning Glory? (Deluxe Rema...
# 97  5Nux7ozBJ5KJ02QYWwrneR                  I Don't Care (with Justin Bieber)
# 98  4PgleR09JVnm3zY1fW3XBA                                          24K Magic
# 99  270o30h7cAlEhBnbuSpFZq                                          El Dorado
#
#    release_date  total_tracks  \
# ...

# %% [markdown]
# # ARTISTS

# %%
#artist_id,artist_name,url

# %%
data['items'][4]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#   'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#   'id': '246dkjvS1zLTtiykXe5h60',
#   'name': 'Post Malone',
#   'type': 'artist',
#   'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#   'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#   'id': '1zNqQNIdeOUZHb8zbZRFMX',
#   'name': 'Swae Lee',
#   'type': 'artist',
#   'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}]

# %%
for artist in data['items'][4]['track']['artists']:
    print(artist['name'])
# Out:
# Post Malone
# Swae Lee

# %%
artist_id,artist_name,url = [],[],[]
for item in data ['items']:
    for artist in item['track']['artists']:
        artist_id.append(artist['id'])
        artist_name.append(artist['name'])
        url.append(artist['external_urls']['spotify'])
        
        artist_dict = {'artist_id':artist_id, 'artist_name':artist_name,'url':url}

# %%
df_artists = pd.DataFrame( artist_dict )

# %%
df_artists
# Out:
#                   artist_id                 artist_name  \
# 0    1Xyo4u8uXC1ZmMpatF05PJ                  The Weeknd
# 1    6eUKZXaKkcviH0Ku9w2n3V                  Ed Sheeran
# 2    4GNC7GD6oZMSxPGyXy4MNB               Lewis Capaldi
# 3    2NjfBq1NflQcKSeiDooVjY                 Tones And I
# 4    246dkjvS1zLTtiykXe5h60                 Post Malone
# ..                      ...                         ...
# 128  1WsYCXdezMjn0KoIrLvMmC  Ed Sheeran & Justin Bieber
# 129  1uNFoZAHBGtllmzznpCI3s               Justin Bieber
# 130  0du5cEVh5yTK9QJze8zA0C                  Bruno Mars
# 131  6fWVd57NKTalqvmjRd2t8Z                    24kGoldn
# 132  6ASri4ePR7RlsvIQgWPJpS                   iann dior
#
#                                                    url
# 0    https://open.spotify.com/artist/1Xyo4u8uXC1ZmM...
# 1    https://open.spotify.com/artist/6eUKZXaKkcviH0...
# 2    https://open.spotify.com/artist/4GNC7GD6oZMSxP...
# 3    https://open.spotify.com/artist/2NjfBq1NflQcKS...
# ...

# %%
df_artists.drop_duplicates(subset=['artist_id'])
# Out:
#                   artist_id                 artist_name  \
# 0    1Xyo4u8uXC1ZmMpatF05PJ                  The Weeknd
# 1    6eUKZXaKkcviH0Ku9w2n3V                  Ed Sheeran
# 2    4GNC7GD6oZMSxPGyXy4MNB               Lewis Capaldi
# 3    2NjfBq1NflQcKSeiDooVjY                 Tones And I
# 4    246dkjvS1zLTtiykXe5h60                 Post Malone
# ..                      ...                         ...
# 126  37hAfseJWi0G3Scife12Il                  City Girls
# 127  2DaxqgrOhkeH0fpeiQq2f4                       Oasis
# 128  1WsYCXdezMjn0KoIrLvMmC  Ed Sheeran & Justin Bieber
# 131  6fWVd57NKTalqvmjRd2t8Z                    24kGoldn
# 132  6ASri4ePR7RlsvIQgWPJpS                   iann dior
#
#                                                    url
# 0    https://open.spotify.com/artist/1Xyo4u8uXC1ZmM...
# 1    https://open.spotify.com/artist/6eUKZXaKkcviH0...
# 2    https://open.spotify.com/artist/4GNC7GD6oZMSxP...
# 3    https://open.spotify.com/artist/2NjfBq1NflQcKS...
# ...

# %% [markdown]
# ## SONGS

# %%
#song_id, song_name, album_track_number ,song_duration, song_popularity,song_added,album_id ,artist_id,

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
# ...

# %%
#song_id
data['items'][0]['track']['id']
# Out:
# '0VjIjW4GlUZAMYd2vXMi3b'

# %%
#song_name
data['items'][0]['track']['name']
# Out:
# 'Blinding Lights'

# %%
 #album_track_number
data['items'][0]['track']['track_number']
# Out:
# 9

# %%
#song_duration
data['items'][0]['track']['duration_ms']
# Out:
# 200040

# %%
#song_popularity
data['items'][0]['track']['popularity']
# Out:
# 92

# %%
#song_added
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
#album_id
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
#artist_id
data['items'][0]['track']['artists'][0]['id']
# Out:
# '1Xyo4u8uXC1ZmMpatF05PJ'

# %%
#song_url
data['items'][0]['track']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'

# %%
song_id, song_name, album_track_number, song_duration, song_popularity, song_added, album_id, artist_id, url = [], [], [], [], [], [], [], [], []

for item in data['items']:
    song_id.append(item['track']['id'])
    song_name.append(item['track']['name'])
    album_track_number.append(item['track']['track_number'])
    song_duration.append(item['track']['duration_ms'])
    song_popularity.append(item['track']['popularity'])
    song_added.append(item['album']['release_date']) 
    album_id.append(item['track']['album']['id'])
    artist_id.append(item['track']['artists'][0]['id'])
    url.append(item['track']['external_urls']['spotify'])
    
song_dict = {
    'song_id': song_id,
    'song_name': song_name,
    'album_track_number': album_track_number,
    'song_duration': song_duration,
    'song_popularity': song_popularity,
    'song_added': song_added,
    'album_id': album_id,
    'artist_id': artist_id,
    'url': url
}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 9
#       7 song_duration.append(item['track']['duration_ms'])
#       8 song_popularity.append(item['track']['popularity'])
# ----> 9 song_added.append(item['album']['release_date'])
#      10 album_id.append(item['track']['album']['id'])
#      11 artist_id.append(item['track']['artists'][0]['id'])
#
# KeyError: 'album'
